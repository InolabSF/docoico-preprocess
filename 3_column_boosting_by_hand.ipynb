# %% [markdown]
# Tagging destination by
#
# [TripAdvisor Group](https://developer-tripadvisor.com/content-api/business-content/categories-subcategories-and-types/)
#
# - Boat Tours & Water Sports
# - Casinos & Gambling
# - Classes & Workshops
# - Concerts & Shows
# - Events
# - Food & Drink
# - Fun & Games
# - Museums
# - Nature & Parks
# - Nightlife
# - Outdoor Activities
# - Shopping
# - Sights & Landmarks
# - Spas & Wellness
# - Tours
# - Transportation
# - Traveler Resources
# - Water & Amusement Parks
# - Zoos & Aquarium

# %%
import numpy as np
import pandas as pd
import os
import urllib.request
import urllib.parse
import json

GOOGLE_API_KEY = os.environ['GOOGLE_API_KEY']
pd.set_option('display.max_columns', 200)
df = pd.read_csv('./boosted/destination.csv', sep=',')
df
# Out:
#     Id            Title Subtitle Desc             Created at  \
# 0    1     プライベートビーチと夕日       -    -   August 21, 2018 18:13
# 1    2      トロトロ軟骨ソーキそば       -    -   August 21, 2018 18:11
# 2    3            なばなの里       -    -   August 21, 2018 18:13
# 3    4           ラピュタの道       -    -   August 21, 2018 18:13
# 4    5          ハウステンボス       -    -   August 21, 2018 18:13
# 5    6       北海道 美瑛 青い池       -    -   August 21, 2018 18:12
# 6    7          山口 角島大橋       -    -   August 21, 2018 18:12
# 7    8              屋久島       -    -   August 21, 2018 18:12
# 8    9         岐阜県　モネの池       -    -   August 21, 2018 18:12
# 9   10        北海道　神威岬灯台       -    -   August 21, 2018 18:12
# 10  11     鹿児島県　日本最南端の駅       -    -   August 21, 2018 18:11
# 11  12           香川県　直島       -    -   August 21, 2018 18:13
# 12  13         鳥取県　鳥取砂丘       -    -   August 21, 2018 18:12
# 13  14  三重県　二見興玉神社（夫婦岩）       -    -   August 21, 2018 18:13
# ...
