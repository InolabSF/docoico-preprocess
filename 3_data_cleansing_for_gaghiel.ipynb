# %%
import pandas as pd
import numpy as np
import os
import urllib.request
import json

pd.set_option('display.max_columns', 200)

# %%
#destination
df = pd.read_csv('./boosted/destination.csv', sep=',')
columns = df.columns.drop(['Subtitle', 'Desc', 'Category', 'Created at', 'Updated at', 'Created at [Destination articles]', 'Updated at [Destination articles]'])
df_destination = df[columns]
df_destination.to_csv('./datas/destination.csv', encoding='utf-8', index=False)
df_destination
# Out:
#     Id            Title        Lat         Lng             Address  \
# 0    1     プライベートビーチと夕日  26.735208  128.160385      沖縄県国頭郡国頭村奥間913
# 1    2      トロトロ軟骨ソーキそば  24.539505  124.300313       沖縄県石垣市字伊原間360
# 2    3            なばなの里  35.081633  136.702875     重県桑名市長島町駒江漆畑２７０
# 3    4           ラピュタの道  32.950388  131.010359            熊本県阿蘇市狩尾
# 4    5          ハウステンボス  33.089751  129.790358  長崎県佐世保市ハウステンボス町１−１
# 5    6       北海道 美瑛 青い池  43.473760  142.638212         北海道上川郡美瑛町白金
# 6    7          山口 角島大橋  36.710414  136.909387    山口県下関市 県道 276 号線
# 7    8              屋久島  30.371299  130.666468         鹿児島県熊毛郡屋久島町
# 8    9         岐阜県　モネの池  35.651713  136.821435   岐阜県関市板取上ケ瀬1643−17
# 9   10        北海道　神威岬灯台  43.327853  140.356805         北海道積丹町大字神岬町
# 10  11     鹿児島県　日本最南端の駅  31.200527  130.596900      鹿児島県指宿市山川大山602
# 11  12           香川県　直島  34.457017  133.974644    香川県香川郡直島町2249−40
# 12  13         鳥取県　鳥取砂丘  35.512309  134.227206     鳥取県鳥取市相生町4丁目411
# ...

# %%
# user
df = pd.read_csv('./boosted/user.csv', sep=',')
columns = df.columns.drop(['Email', 'Reset password sent at', 'Remember created at', 'Current sign in at', 'Last sign in at', 'Current sign in ip', 'Last sign in ip', 'Created at', 'Updated at', 'Admin', 'Line', 'Name', 'Access token', 'Refresh token'])
df_user = df.query('Admin != "t"')[columns]
df_user = df_user.rename(columns={'Id': 'User'})
df_user
# Out:
#     User  Sign in count                                         User agent  \
# 1      2              1  Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like...
# 2      3              1  Mozilla/5.0 (Linux; Android 5.0; SM-G900P Buil...
# 3      4              1  Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like...
# 4      5              1  Mozilla/5.0 (Linux; Android 8.1.0; Nexus 6P Bu...
# 5      6              1  Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like...
# 6      7              1  Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like...
# 7      8              1  Mozilla/5.0 (Linux; Android 7.0; SC-05G Build/...
# 8      9              1  Mozilla/5.0 (iPhone; CPU iPhone OS 11_4 like M...
# 9     10              1  Mozilla/5.0 (iPhone; CPU iPhone OS 11_3 like M...
# 10    11              1  Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like...
# 11    12              1  Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like...
# ...
